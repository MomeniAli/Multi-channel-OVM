# %%
import sys
sys.path.append("/home/adminlwe/Documents/lwe-opu/experiment/model_training/onn_online_training")

# %% [markdown]
# ### ONN training with Physics-aware algorithm

# %%
import result
result.plot_history(result.default_avg_batch, end_iter=28000)
# Out:
# /home/adminlwe/Documents/lwe-opu/experiment/model_training/onn_online_training/result.py:68: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
# ...

# %% [markdown]
# ### ONN training with Physics-aware algorithm (Binary Decision)

# %%
import result_binary_decision
result_binary_decision.plot_history(result_binary_decision.default_avg_batch, end_iter=28000)
# Out:
# Best metrics:
#   train_loss: 0.177636 @ iter 19163.00
#   test_loss:  0.335293 @ iter 17000.00
#   train_acc:  0.973333 @ iter 15188.00
#   test_acc:   0.915 @ iter 17000.00
# ...

# %% [markdown]
# ### ONN training with Physics-aware algorithm (MIX)

# %%
import result_mix
result_mix.plot_history(result_mix.default_avg_batch, end_iter=26000)
# Out:
# /home/adminlwe/Documents/lwe-opu/experiment/model_training/onn_online_training/result_mix.py:81: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
# ...

# %% [markdown]
# ### ONN training with Physics-aware algorithm (MIX) Face

# %%
import result_mix_face
result_mix_face.plot_history(result_mix_face.default_avg_batch, end_iter=26000, y_log=False)
# Out:
# Best metrics:
#   train_loss:       0.0199721 @ iter 14820.50
#   test_loss:        0.0236286 @ iter 14500.00
#   train_pixel_err:  2.01994 @ iter 11575.50
#   test_pixel_err:   2.46108 @ iter 13000.00
# ...

# %% [markdown]
# ### ONN training with Physics-aware algorithm (MIX) VLM

# %%
import result_mix_VLM
result_mix_VLM.plot_history(result_mix_VLM.default_avg_batch, end_iter=26000, y_log=False)
# Out:
# /home/adminlwe/Documents/lwe-opu/experiment/model_training/onn_online_training/result_mix_VLM.py:80: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
# ...
